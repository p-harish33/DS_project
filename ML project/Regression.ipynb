# %%
import matplotlib.pyplot as plt,pandas as pd,seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('Cellphone.csv')

# %%
df
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# ...

# %%
# Product_id - A unique identifier for each cellphone.
# Price - The price of the cellphone.
# Sale - The number of units sold.
# weight - The weight of the cellphone (grams).
# resoloution - The screen size or resolution (possibly in inches).
# ppi - Pixels per inch (screen density).
# cpu core - The number of CPU cores in the device.
# cpu freq - The CPU clock speed (GHz or MHz).
# internal mem - Internal storage capacity (GB).
# ram - The RAM capacity (GB).
# RearCam - The megapixel value of the rear camera.
# Front_Cam - The megapixel value of the front camera.
# battery - The battery capacity (mAh).
# thickness - The thickness of the phone (mm).

# %%
df.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
df.drop(columns=['Product_id'],inplace=True)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Price'], kde=True, bins=50, color='blue')
plt.show()

# %%
df.columns
# Out:
# Index(['Price', 'Sale', 'weight', 'resoloution', 'ppi', 'cpu core', 'cpu freq',
#        'internal mem', 'ram', 'RearCam', 'Front_Cam', 'battery', 'thickness'],
#       dtype='object')

# %%
for i in df.columns:
    plt.figure()
    plt.boxplot(df[i])
    plt.title(f'picture of {i}')
    plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
x = df.drop(columns=["Price"])
y = df["Price"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
scaler=StandardScaler()
sc=scaler.fit_transform(df)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9539561704745615

# %%
o=reg.predict(x_train)

# %%
r2_score(o,y_train)*100
# Out:
# 95.03092018766304

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
reg = RandomForestClassifier(n_estimators=100, random_state=42)
reg.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = reg.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8496658793991334

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(reg,x,y,cv=5,scoring='r2')
score*100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 from sklearn.model_selection import cross_val_score
# ----> 2 score=cross_val_score(reg,x,y,cv=5,scoring='r2')
#       3 score*100
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...
