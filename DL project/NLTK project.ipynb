# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
import nltk

# %%
df=pd.read_csv('reviews.csv')
df
# Out:
#       rating              date  \
# 0          2  30 December 2024
# 1          1   4 November 2024
# 2          1   31 October 2024
# 3          5    29 August 2024
# 4          2  31 December 2024
# ...      ...               ...
# 4615       1  27 November 2024
# 4616       4   5 December 2024
# 4617       1  13 November 2024
# 4618       5  17 November 2024
# 4619       1   22 October 2024
#
#                                                  review platform
# 0     I was using it for long time, but have to stop...  blinkit
# 1     Loving the fast deliveries and mostly they are...  blinkit
# 2     The customer support is very disappointing. I ...  blinkit
# 3     I've been using Blinkit for a while now, and i...  blinkit
# 4     Blinkit was my go to app and it was rare that ...  blinkit
# ...                                                 ...      ...
# 4615  I have deposited ₹1300 to my zepto wallet to o...    zepto
# 4616  Prices r competitive for certain items. Not fo...    zepto
# 4617  Worst delivery ever. They delivered a broken p...    zepto
# 4618  I had a great experience with zepto, the quali...    zepto
# 4619  The worst possible delivery app ever, will not...    zepto
#
# [4620 rows x 4 columns]

# %%
df['review'].shape
# Out:
# (4620,)

# %%
df['rating'].unique()
# Out:
# array([2, 1, 5, 3, 4], dtype=int64)

# %%
df1=df[['review','rating']]
df1
# Out:
#                                                  review  rating
# 0     I was using it for long time, but have to stop...       2
# 1     Loving the fast deliveries and mostly they are...       1
# 2     The customer support is very disappointing. I ...       1
# 3     I've been using Blinkit for a while now, and i...       5
# 4     Blinkit was my go to app and it was rare that ...       2
# ...                                                 ...     ...
# 4615  I have deposited ₹1300 to my zepto wallet to o...       1
# 4616  Prices r competitive for certain items. Not fo...       4
# 4617  Worst delivery ever. They delivered a broken p...       1
# 4618  I had a great experience with zepto, the quali...       5
# 4619  The worst possible delivery app ever, will not...       1
#
# [4620 rows x 2 columns]

# %%
import re

# %%
# step 1 = cleaned \\ [^A-Za-z]+', ' ' ,, puntuation, fullstop, exclamatory....

def clean(text):
    text = re.sub('[^A-Za-z]+', ' ', text)
    return text

# %%
df1['cleaned']=df1['review'].apply(clean)
df1
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7528\3335034037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['cleaned']=df1['review'].apply(clean)
#                                                  review  rating  \
# 0     I was using it for long time, but have to stop...       2
# 1     Loving the fast deliveries and mostly they are...       1
# 2     The customer support is very disappointing. I ...       1
# 3     I've been using Blinkit for a while now, and i...       5
# 4     Blinkit was my go to app and it was rare that ...       2
# ...                                                 ...     ...
# 4615  I have deposited ₹1300 to my zepto wallet to o...       1
# 4616  Prices r competitive for certain items. Not fo...       4
# 4617  Worst delivery ever. They delivered a broken p...       1
# 4618  I had a great experience with zepto, the quali...       5
# 4619  The worst possible delivery app ever, will not...       1
#
#                                                 cleaned
# 0     I was using it for long time but have to stop ...
# 1     Loving the fast deliveries and mostly they are...
# 2     The customer support is very disappointing I r...
# 3     I ve been using Blinkit for a while now and it...
# 4     Blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  I have deposited to my zepto wallet to order a...
# 4616  Prices r competitive for certain items Not for...
# 4617  Worst delivery ever They delivered a broken pr...
# 4618  I had a great experience with zepto the qualit...
# 4619  The worst possible delivery app ever will not ...
#
# [4620 rows x 3 columns]

# %%
# step 2 = lowercase/upercase remove

df1['Lowercase']= df1['cleaned'].apply(lambda x: " ".join(word.lower() for word in x.split()))
df1
# Out:
#                                                  review  rating  \
# 0     I was using it for long time, but have to stop...       2
# 1     Loving the fast deliveries and mostly they are...       1
# 2     The customer support is very disappointing. I ...       1
# 3     I've been using Blinkit for a while now, and i...       5
# 4     Blinkit was my go to app and it was rare that ...       2
# ...                                                 ...     ...
# 4615  I have deposited ₹1300 to my zepto wallet to o...       1
# 4616  Prices r competitive for certain items. Not fo...       4
# 4617  Worst delivery ever. They delivered a broken p...       1
# 4618  I had a great experience with zepto, the quali...       5
# 4619  The worst possible delivery app ever, will not...       1
#
#                                                 cleaned  \
# 0     I was using it for long time but have to stop ...
# 1     Loving the fast deliveries and mostly they are...
# 2     The customer support is very disappointing I r...
# 3     I ve been using Blinkit for a while now and it...
# 4     Blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  I have deposited to my zepto wallet to order a...
# 4616  Prices r competitive for certain items Not for...
# 4617  Worst delivery ever They delivered a broken pr...
# 4618  I had a great experience with zepto the qualit...
# 4619  The worst possible delivery app ever will not ...
#
#                                               Lowercase
# 0     i was using it for long time but have to stop ...
# 1     loving the fast deliveries and mostly they are...
# 2     the customer support is very disappointing i r...
# 3     i ve been using blinkit for a while now and it...
# 4     blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  i have deposited to my zepto wallet to order a...
# 4616  prices r competitive for certain items not for...
# 4617  worst delivery ever they delivered a broken pr...
# 4618  i had a great experience with zepto the qualit...
# 4619  the worst possible delivery app ever will not ...
#
# [4620 rows x 4 columns]

# %%
# step 3 = remove stopwords

from nltk.corpus import stopwords
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
df1['stopwords'] = df1['Lowercase'].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))
df1
# Out:
#                                                  review  rating  \
# 0     I was using it for long time, but have to stop...       2
# 1     Loving the fast deliveries and mostly they are...       1
# 2     The customer support is very disappointing. I ...       1
# 3     I've been using Blinkit for a while now, and i...       5
# 4     Blinkit was my go to app and it was rare that ...       2
# ...                                                 ...     ...
# 4615  I have deposited ₹1300 to my zepto wallet to o...       1
# 4616  Prices r competitive for certain items. Not fo...       4
# 4617  Worst delivery ever. They delivered a broken p...       1
# 4618  I had a great experience with zepto, the quali...       5
# 4619  The worst possible delivery app ever, will not...       1
#
#                                                 cleaned  \
# 0     I was using it for long time but have to stop ...
# 1     Loving the fast deliveries and mostly they are...
# 2     The customer support is very disappointing I r...
# 3     I ve been using Blinkit for a while now and it...
# 4     Blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  I have deposited to my zepto wallet to order a...
# 4616  Prices r competitive for certain items Not for...
# 4617  Worst delivery ever They delivered a broken pr...
# 4618  I had a great experience with zepto the qualit...
# 4619  The worst possible delivery app ever will not ...
#
#                                               Lowercase  \
# 0     i was using it for long time but have to stop ...
# 1     loving the fast deliveries and mostly they are...
# 2     the customer support is very disappointing i r...
# 3     i ve been using blinkit for a while now and it...
# 4     blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  i have deposited to my zepto wallet to order a...
# 4616  prices r competitive for certain items not for...
# 4617  worst delivery ever they delivered a broken pr...
# 4618  i had a great experience with zepto the qualit...
# 4619  the worst possible delivery app ever will not ...
#
#                                               stopwords
# 0     using long time stop using recently got used i...
# 1     loving fast deliveries mostly great quick deli...
# 2     customer support disappointing recently bought...
# 3     using blinkit become go app grocery shopping a...
# 4     blinkit go app rare disappointed today disappo...
# ...                                                 ...
# 4615  deposited zepto wallet order watch depositing ...
# 4616  prices r competitive certain items packing goo...
# 4617  worst delivery ever delivered broken product s...
# 4618  great experience zepto quality level faster de...
# 4619  worst possible delivery app ever let cancel or...
#
# [4620 rows x 5 columns]

# %%
# step 4 = remove token words, pos tag

from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
from nltk import pos_tag

# POS tagger dictionary
pos_dict = {'J': wordnet.ADJ, 'V': wordnet.VERB, 'N': wordnet.NOUN, 'R': wordnet.ADV}

def token_pos(text):
    return [
        (word, pos_dict.get(tag[0]))
        for word, tag in pos_tag(word_tokenize(text))
    ]

# %%
df1['POS tagged'] = df1["stopwords"].apply(token_pos)
df1
# Out:
#                                                  review  rating  \
# 0     I was using it for long time, but have to stop...       2
# 1     Loving the fast deliveries and mostly they are...       1
# 2     The customer support is very disappointing. I ...       1
# 3     I've been using Blinkit for a while now, and i...       5
# 4     Blinkit was my go to app and it was rare that ...       2
# ...                                                 ...     ...
# 4615  I have deposited ₹1300 to my zepto wallet to o...       1
# 4616  Prices r competitive for certain items. Not fo...       4
# 4617  Worst delivery ever. They delivered a broken p...       1
# 4618  I had a great experience with zepto, the quali...       5
# 4619  The worst possible delivery app ever, will not...       1
#
#                                                 cleaned  \
# 0     I was using it for long time but have to stop ...
# 1     Loving the fast deliveries and mostly they are...
# 2     The customer support is very disappointing I r...
# 3     I ve been using Blinkit for a while now and it...
# 4     Blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  I have deposited to my zepto wallet to order a...
# 4616  Prices r competitive for certain items Not for...
# 4617  Worst delivery ever They delivered a broken pr...
# 4618  I had a great experience with zepto the qualit...
# 4619  The worst possible delivery app ever will not ...
#
#                                               Lowercase  \
# 0     i was using it for long time but have to stop ...
# 1     loving the fast deliveries and mostly they are...
# 2     the customer support is very disappointing i r...
# 3     i ve been using blinkit for a while now and it...
# 4     blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  i have deposited to my zepto wallet to order a...
# 4616  prices r competitive for certain items not for...
# 4617  worst delivery ever they delivered a broken pr...
# 4618  i had a great experience with zepto the qualit...
# 4619  the worst possible delivery app ever will not ...
#
#                                               stopwords  \
# 0     using long time stop using recently got used i...
# 1     loving fast deliveries mostly great quick deli...
# 2     customer support disappointing recently bought...
# 3     using blinkit become go app grocery shopping a...
# 4     blinkit go app rare disappointed today disappo...
# ...                                                 ...
# 4615  deposited zepto wallet order watch depositing ...
# 4616  prices r competitive certain items packing goo...
# 4617  worst delivery ever delivered broken product s...
# 4618  great experience zepto quality level faster de...
# 4619  worst possible delivery app ever let cancel or...
#
#                                              POS tagged
# 0     [(using, v), (long, a), (time, n), (stop, n), ...
# 1     [(loving, v), (fast, a), (deliveries, n), (mos...
# 2     [(customer, n), (support, n), (disappointing, ...
# 3     [(using, v), (blinkit, n), (become, n), (go, v...
# 4     [(blinkit, n), (go, v), (app, r), (rare, a), (...
# ...                                                 ...
# 4615  [(deposited, v), (zepto, None), (wallet, a), (...
# 4616  [(prices, n), (r, v), (competitive, a), (certa...
# 4617  [(worst, r), (delivery, n), (ever, r), (delive...
# 4618  [(great, a), (experience, n), (zepto, n), (qua...
# 4619  [(worst, a), (possible, a), (delivery, n), (ap...
#
# [4620 rows x 6 columns]

# %%
# step 5 = lemmatation method

from nltk.stem import WordNetLemmatizer

# Initialize the lemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
        if not pos:  # If no POS tag is available, use the word as is
            lemma = word
        else:
            # Lemmatize based on the POS tag
            lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        lemma_rew = lemma_rew + " " + lemma  # Add the lemma to the result string
    return lemma_rew

# Assuming df2 is your dataframe and 'POS tagged' contains POS-tagged text
df1['Lemma'] = df1['POS tagged'].apply(lemmatize)
df1
# Out:
#                                                  review  rating  \
# 0     I was using it for long time, but have to stop...       2
# 1     Loving the fast deliveries and mostly they are...       1
# 2     The customer support is very disappointing. I ...       1
# 3     I've been using Blinkit for a while now, and i...       5
# 4     Blinkit was my go to app and it was rare that ...       2
# ...                                                 ...     ...
# 4615  I have deposited ₹1300 to my zepto wallet to o...       1
# 4616  Prices r competitive for certain items. Not fo...       4
# 4617  Worst delivery ever. They delivered a broken p...       1
# 4618  I had a great experience with zepto, the quali...       5
# 4619  The worst possible delivery app ever, will not...       1
#
#                                                 cleaned  \
# 0     I was using it for long time but have to stop ...
# 1     Loving the fast deliveries and mostly they are...
# 2     The customer support is very disappointing I r...
# 3     I ve been using Blinkit for a while now and it...
# 4     Blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  I have deposited to my zepto wallet to order a...
# 4616  Prices r competitive for certain items Not for...
# 4617  Worst delivery ever They delivered a broken pr...
# 4618  I had a great experience with zepto the qualit...
# 4619  The worst possible delivery app ever will not ...
#
#                                               Lowercase  \
# 0     i was using it for long time but have to stop ...
# 1     loving the fast deliveries and mostly they are...
# 2     the customer support is very disappointing i r...
# 3     i ve been using blinkit for a while now and it...
# 4     blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  i have deposited to my zepto wallet to order a...
# 4616  prices r competitive for certain items not for...
# 4617  worst delivery ever they delivered a broken pr...
# 4618  i had a great experience with zepto the qualit...
# 4619  the worst possible delivery app ever will not ...
#
#                                               stopwords  \
# 0     using long time stop using recently got used i...
# 1     loving fast deliveries mostly great quick deli...
# 2     customer support disappointing recently bought...
# 3     using blinkit become go app grocery shopping a...
# 4     blinkit go app rare disappointed today disappo...
# ...                                                 ...
# 4615  deposited zepto wallet order watch depositing ...
# 4616  prices r competitive certain items packing goo...
# 4617  worst delivery ever delivered broken product s...
# 4618  great experience zepto quality level faster de...
# 4619  worst possible delivery app ever let cancel or...
#
#                                              POS tagged  \
# 0     [(using, v), (long, a), (time, n), (stop, n), ...
# 1     [(loving, v), (fast, a), (deliveries, n), (mos...
# 2     [(customer, n), (support, n), (disappointing, ...
# 3     [(using, v), (blinkit, n), (become, n), (go, v...
# 4     [(blinkit, n), (go, v), (app, r), (rare, a), (...
# ...                                                 ...
# 4615  [(deposited, v), (zepto, None), (wallet, a), (...
# 4616  [(prices, n), (r, v), (competitive, a), (certa...
# 4617  [(worst, r), (delivery, n), (ever, r), (delive...
# 4618  [(great, a), (experience, n), (zepto, n), (qua...
# 4619  [(worst, a), (possible, a), (delivery, n), (ap...
#
#                                                   Lemma
# 0       use long time stop use recently get used ite...
# 1       love fast delivery mostly great quick delive...
# 2       customer support disappoint recently buy ele...
# 3       use blinkit become go app grocery shopping a...
# 4       blinkit go app rare disappoint today disappo...
# ...                                                 ...
# 4615    deposit zepto wallet order watch deposit mon...
# 4616    price r competitive certain item pack good d...
# 4617    worst delivery ever deliver broken product s...
# 4618    great experience zepto quality level faster ...
# 4619    bad possible delivery app ever let cancel or...
#
# [4620 rows x 7 columns]

# %%
#for i in df1['rating']:
 #   if i<=2:
  #      print('Bad')
   # elif i>2 and i<=4:
    #    print('Average')
    #else:
     #   print('Good')
df1['rating_category'] = df1['rating'].apply(lambda x: 'Bad' if x <= 2 else 'Average' if x <= 4 else 'Good')
df1
# Out:
#                                                  review  rating  \
# 0     I was using it for long time, but have to stop...       2
# 1     Loving the fast deliveries and mostly they are...       1
# 2     The customer support is very disappointing. I ...       1
# 3     I've been using Blinkit for a while now, and i...       5
# 4     Blinkit was my go to app and it was rare that ...       2
# ...                                                 ...     ...
# 4615  I have deposited ₹1300 to my zepto wallet to o...       1
# 4616  Prices r competitive for certain items. Not fo...       4
# 4617  Worst delivery ever. They delivered a broken p...       1
# 4618  I had a great experience with zepto, the quali...       5
# 4619  The worst possible delivery app ever, will not...       1
#
#                                                 cleaned  \
# 0     I was using it for long time but have to stop ...
# 1     Loving the fast deliveries and mostly they are...
# 2     The customer support is very disappointing I r...
# 3     I ve been using Blinkit for a while now and it...
# 4     Blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  I have deposited to my zepto wallet to order a...
# 4616  Prices r competitive for certain items Not for...
# 4617  Worst delivery ever They delivered a broken pr...
# 4618  I had a great experience with zepto the qualit...
# 4619  The worst possible delivery app ever will not ...
#
#                                               Lowercase  \
# 0     i was using it for long time but have to stop ...
# 1     loving the fast deliveries and mostly they are...
# 2     the customer support is very disappointing i r...
# 3     i ve been using blinkit for a while now and it...
# 4     blinkit was my go to app and it was rare that ...
# ...                                                 ...
# 4615  i have deposited to my zepto wallet to order a...
# 4616  prices r competitive for certain items not for...
# 4617  worst delivery ever they delivered a broken pr...
# 4618  i had a great experience with zepto the qualit...
# 4619  the worst possible delivery app ever will not ...
#
#                                               stopwords  \
# 0     using long time stop using recently got used i...
# 1     loving fast deliveries mostly great quick deli...
# 2     customer support disappointing recently bought...
# 3     using blinkit become go app grocery shopping a...
# 4     blinkit go app rare disappointed today disappo...
# ...                                                 ...
# 4615  deposited zepto wallet order watch depositing ...
# 4616  prices r competitive certain items packing goo...
# 4617  worst delivery ever delivered broken product s...
# 4618  great experience zepto quality level faster de...
# 4619  worst possible delivery app ever let cancel or...
#
#                                              POS tagged  \
# 0     [(using, v), (long, a), (time, n), (stop, n), ...
# 1     [(loving, v), (fast, a), (deliveries, n), (mos...
# 2     [(customer, n), (support, n), (disappointing, ...
# 3     [(using, v), (blinkit, n), (become, n), (go, v...
# 4     [(blinkit, n), (go, v), (app, r), (rare, a), (...
# ...                                                 ...
# 4615  [(deposited, v), (zepto, None), (wallet, a), (...
# 4616  [(prices, n), (r, v), (competitive, a), (certa...
# 4617  [(worst, r), (delivery, n), (ever, r), (delive...
# 4618  [(great, a), (experience, n), (zepto, n), (qua...
# 4619  [(worst, a), (possible, a), (delivery, n), (ap...
#
#                                                   Lemma rating_category
# 0       use long time stop use recently get used ite...             Bad
# 1       love fast delivery mostly great quick delive...             Bad
# 2       customer support disappoint recently buy ele...             Bad
# 3       use blinkit become go app grocery shopping a...            Good
# 4       blinkit go app rare disappoint today disappo...             Bad
# ...                                                 ...             ...
# 4615    deposit zepto wallet order watch deposit mon...             Bad
# 4616    price r competitive certain item pack good d...         Average
# 4617    worst delivery ever deliver broken product s...             Bad
# 4618    great experience zepto quality level faster ...            Good
# 4619    bad possible delivery app ever let cancel or...             Bad
#
# [4620 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score

# %%
X = df1['Lemma']
y = df1['rating_category']

# %%
# Vectorize the text
vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

# %%
lg=LogisticRegression()

# %%
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(X_test)

# %%
print(accuracy_score(y_pred,y_test)*100)
# Out:
# 85.71428571428571
